# %% [markdown]
# Data Source : https://www.kaggle.com/datasets/toramky/automobile-dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
data = pd.read_csv('Automobile_data.csv')
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %%
data.shape
# Out:
# (205, 26)

# %%
data.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
data.isin(['?']).sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
data.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
data['normalized-losses'] = data['normalized-losses'].replace('?',0)
data['normalized-losses'] = data['normalized-losses'].astype('int')
data['normalized-losses'].unique()
# Out:
# array([  0, 164, 158, 192, 188, 121,  98,  81, 118, 148, 110, 145, 137,
#        101,  78, 106,  85, 107, 104, 113, 150, 129, 115,  93, 142, 161,
#        153, 125, 128, 122, 103, 168, 108, 194, 231, 119, 154,  74, 186,
#         83, 102,  89,  87,  77,  91, 134,  65, 197,  90,  94, 256,  95])

# %%
data['num-of-doors'] = data['num-of-doors'].replace('?','four')
data['num-of-doors'] = data['num-of-doors'].replace('four',4)
data['num-of-doors'] = data['num-of-doors'].replace('two',2)
data['num-of-doors'].unique()
# Out:
# array([2, 4], dtype=int64)

# %%
data['bore'] = data['bore'].replace('?',0)
data['bore'] = data['bore'].astype('float')
data['bore'].unique()
# Out:
# array([3.47, 2.68, 3.19, 3.13, 3.5 , 3.31, 3.62, 2.91, 3.03, 2.97, 3.34,
#        3.6 , 2.92, 3.15, 3.43, 3.63, 3.54, 3.08, 0.  , 3.39, 3.76, 3.58,
#        3.46, 3.8 , 3.78, 3.17, 3.35, 3.59, 2.99, 3.33, 3.7 , 3.61, 3.94,
#        3.74, 2.54, 3.05, 3.27, 3.24, 3.01])

# %%
data['stroke'] = data['stroke'].replace('?',0)
data['stroke'] = data['stroke'].astype('float')
data['stroke'].unique()
# Out:
# array([2.68, 3.47, 3.4 , 2.8 , 3.19, 3.39, 3.03, 3.11, 3.23, 3.46, 3.9 ,
#        3.41, 3.07, 3.58, 4.17, 2.76, 3.15, 0.  , 3.16, 3.64, 3.1 , 3.35,
#        3.12, 3.86, 3.29, 3.27, 3.52, 2.19, 3.21, 2.9 , 2.07, 2.36, 2.64,
#        3.08, 3.5 , 3.54, 2.87])

# %%
data['horsepower'] = data['horsepower'].replace('?',0)
data['horsepower'] = data['horsepower'].astype('int')
data['horsepower'] = data['horsepower'].replace(0,int(data['horsepower'].mean()))
data['horsepower'].unique()
# Out:
# array([111, 154, 102, 115, 110, 140, 160, 101, 121, 182,  48,  70,  68,
#         88, 145,  58,  76,  60,  86, 100,  78,  90, 176, 262, 135,  84,
#         64, 120,  72, 123, 155, 184, 175, 116,  69,  55,  97, 152, 200,
#         95, 142, 143, 207, 288, 103,  73,  82,  94,  62,  56, 112,  92,
#        161, 156,  52,  85, 114, 162, 134, 106])

# %%
data['peak-rpm'] = data['peak-rpm'].replace('?',0)
data['peak-rpm'] = data['peak-rpm'].astype('int')
data['peak-rpm'] = data['peak-rpm'].replace(0,data['peak-rpm'].mean())
data['peak-rpm'] = data['peak-rpm'].astype('int')
data['peak-rpm'].unique()
# Out:
# array([5000, 5500, 5800, 4250, 5400, 5100, 4800, 6000, 4750, 4650, 4200,
#        4350, 4500, 5200, 4150, 5600, 5900, 5750, 5075, 5250, 4900, 4400,
#        6600, 5300])

# %%
data['price'] = data['price'].replace('?',0)
data['price'] = data['price'].astype('int')
data['price'] = data['price'].replace(0,data['price'].mean())
data['price'] = data['price'].astype('int')
data['price'].unique()
# Out:
# array([13495, 16500, 13950, 17450, 15250, 17710, 18920, 23875, 12949,
#        16430, 16925, 20970, 21105, 24565, 30760, 41315, 36880,  5151,
#         6295,  6575,  5572,  6377,  7957,  6229,  6692,  7609,  8558,
#         8921, 12964,  6479,  6855,  5399,  6529,  7129,  7295,  7895,
#         9095,  8845, 10295, 12945, 10345,  6785, 11048, 32250, 35550,
#        36000,  5195,  6095,  6795,  6695,  7395, 10945, 11845, 13645,
#        15645,  8495, 10595, 10245, 10795, 11245, 18280, 18344, 25552,
#        28248, 28176, 31600, 34184, 35056, 40960, 45400, 16503,  5389,
#         6189,  6669,  7689,  9959,  8499, 12629, 14869, 14489,  6989,
#         8189,  9279,  5499,  7099,  6649,  6849,  7349,  7299,  7799,
#         7499,  7999,  8249,  8949,  9549, 13499, 14399, 17199, 19699,
#        18399, 11900, 13200, 12440, 13860, 15580, 16900, 16695, 17075,
#        16630, 17950, 18150, 12764, 22018, 32528, 34028, 37028,  9295,
#         9895, 11850, 12170, 15040, 15510, 18620,  5118,  7053,  7603,
#         7126,  7775,  9960,  9233, 11259,  7463, 10198,  8013, 11694,
#         5348,  6338,  6488,  6918,  7898,  8778,  6938,  7198,  7788,
#         7738,  8358,  9258,  8058,  8238,  9298,  9538,  8449,  9639,
#         9989, 11199, 11549, 17669,  8948, 10698,  9988, 10898, 11248,
#        16558, 15998, 15690, 15750,  7975,  7995,  8195,  9495,  9995,
#        11595,  9980, 13295, 13845, 12290, 12940, 13415, 15985, 16515,
#        18420, 18950, 16845, 19045, 21485, 22470, 22625])

# %%
data.isin(['?']).sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
data['num-of-cylinders'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
data['num-of-cylinders'] = data['num-of-cylinders'].map({'two':2, 'three':3, 'four':4, 'five':5, 'six':6, 'eight':8, 'twelve':12})

# %% [markdown]
# Univariate Analysis

# %%
data.describe()
# Out:
#         symboling  normalized-losses  num-of-doors  wheel-base      length  \
# count  205.000000         205.000000    205.000000  205.000000  205.000000
# mean     0.834146          97.600000      3.131707   98.756585  174.049268
# std      1.245307          58.282073      0.993715    6.021776   12.337289
# min     -2.000000           0.000000      2.000000   86.600000  141.100000
# 25%      0.000000          77.000000      2.000000   94.500000  166.300000
# 50%      1.000000         103.000000      4.000000   97.000000  173.200000
# 75%      2.000000         137.000000      4.000000  102.400000  183.100000
# max      3.000000         256.000000      4.000000  120.900000  208.100000
#
#             width      height  curb-weight  num-of-cylinders  engine-size  \
# count  205.000000  205.000000   205.000000        205.000000   205.000000
# mean    65.907805   53.724878  2555.565854          4.380488   126.907317
# std      2.145204    2.443522   520.680204          1.080854    41.642693
# min     60.300000   47.800000  1488.000000          2.000000    61.000000
# 25%     64.100000   52.000000  2145.000000          4.000000    97.000000
# 50%     65.500000   54.100000  2414.000000          4.000000   120.000000
# 75%     66.900000   55.500000  2935.000000          4.000000   141.000000
# max     72.300000   59.800000  4066.000000         12.000000   326.000000
#
#              bore      stroke  compression-ratio  horsepower     peak-rpm  \
# count  205.000000  205.000000         205.000000  205.000000   205.000000
# mean     3.264780    3.191902          10.142537  104.243902  5124.878049
# std      0.535268    0.549625           3.972040   39.519405   477.004912
# min      0.000000    0.000000           7.000000   48.000000  4150.000000
# 25%      3.130000    3.100000           8.600000   70.000000  4800.000000
# 50%      3.310000    3.290000           9.000000   95.000000  5200.000000
# 75%      3.580000    3.410000           9.400000  116.000000  5500.000000
# max      3.940000    4.170000          23.000000  288.000000  6600.000000
#
#          city-mpg  highway-mpg         price
# count  205.000000   205.000000    205.000000
# mean    25.219512    30.751220  13202.092683
# std      6.542142     6.886443   7868.849609
# min     13.000000    16.000000   5118.000000
# 25%     19.000000    25.000000   7788.000000
# 50%     24.000000    30.000000  10595.000000
# 75%     30.000000    34.000000  16500.000000
# max     49.000000    54.000000  45400.000000

# %%
data['price'].mode()
# Out:
# 0    12949
# dtype: int32

# %%
data.price.sort_values(ascending=False)[:10]
# Out:
# 74     45400
# 16     41315
# 73     40960
# 128    37028
# 17     36880
# 49     36000
# 48     35550
# 72     35056
# 71     34184
# 127    34028
# Name: price, dtype: int32

# %%
data['num-of-cylinders'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['num-of-doors'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='num-of-doors'>

# %%
data['fuel-type'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='fuel-type'>

# %% [markdown]
# Bivariate Analysis

# %%
plt.scatter(data['horsepower'],data['price'])

# %%
plt.scatter(data['bore'],data['price'])

# %%
plt.scatter(data['stroke'],data['price'])

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Multivariate Analysis

# %%
px.scatter(data,y='price',x='horsepower',color='make')

# %%
temp = data[['fuel-type','body-style']]
t = temp.groupby(by=['fuel-type','body-style']).size()
t
# Out:
# fuel-type  body-style
# diesel     hardtop         1
#            hatchback       1
#            sedan          15
#            wagon           3
# gas        convertible     6
#            hardtop         7
#            hatchback      69
#            sedan          81
#            wagon          22
# dtype: int64

# %%
t = t.reset_index()
t.columns = ['fuel-type','body-style','units']
t
# Out:
#   fuel-type   body-style  units
# 0    diesel      hardtop      1
# 1    diesel    hatchback      1
# 2    diesel        sedan     15
# 3    diesel        wagon      3
# 4       gas  convertible      6
# 5       gas      hardtop      7
# 6       gas    hatchback     69
# 7       gas        sedan     81
# 8       gas        wagon     22

# %%
px.bar(t, x='fuel-type', y='units', color='body-style',barmode='group')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    int32
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    int64
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    int64
#  16  engine-size        205 non-null    int64
#  17  fuel-system        205 non-null    object
#  18  bore               205 non-null    float64
#  19  stroke             205 non-null    float64
#  20  compression-ratio  205 non-null    float64
#  21  horsepower         205 non-null    int32
#  22  peak-rpm           205 non-null    int32
#  23  city-mpg           205 non-null    int64
#  24  highway-mpg        205 non-null    int64
#  25  price              205 non-null    int32
# dtypes: float64(7), int32(4), int64(7), object(8)
# memory usage: 38.6+ KB

# %%
def mapper(param):
    uniqueVals = set(data[param]);
    mappedVals = {};
    i = 0
    
    for mem in uniqueVals:
        mappedVals[mem] = i
        i = i + 1
    
    print (mappedVals)
    data[param] =  data[param].map(mappedVals)
    
    return uniqueVals, mappedVals

# %%
mapper('make')
# Out:
# {'volkswagen': 0, 'renault': 1, 'jaguar': 2, 'peugot': 3, 'nissan': 4, 'isuzu': 5, 'audi': 6, 'honda': 7, 'alfa-romero': 8, 'porsche': 9, 'mitsubishi': 10, 'volvo': 11, 'toyota': 12, 'mercury': 13, 'chevrolet': 14, 'bmw': 15, 'saab': 16, 'subaru': 17, 'plymouth': 18, 'mazda': 19, 'dodge': 20, 'mercedes-benz': 21}
# ({'alfa-romero',
#   'audi',
#   'bmw',
#   'chevrolet',
#   'dodge',
#   'honda',
#   'isuzu',
#   'jaguar',
#   'mazda',
#   'mercedes-benz',
#   'mercury',
#   'mitsubishi',
#   'nissan',
#   'peugot',
#   'plymouth',
#   'porsche',
#   'renault',
#   'saab',
#   'subaru',
#   'toyota',
#   'volkswagen',
#   'volvo'},
#  {'volkswagen': 0,
#   'renault': 1,
#   'jaguar': 2,
#   'peugot': 3,
#   'nissan': 4,
#   'isuzu': 5,
#   'audi': 6,
#   'honda': 7,
#   'alfa-romero': 8,
#   'porsche': 9,
#   'mitsubishi': 10,
#   'volvo': 11,
#   'toyota': 12,
#   'mercury': 13,
#   'chevrolet': 14,
#   'bmw': 15,
#   'saab': 16,
#   'subaru': 17,
#   'plymouth': 18,
#   'mazda': 19,
#   'dodge': 20,
#   'mercedes-benz': 21})

# %%
mapper('fuel-type')
mapper('aspiration')
mapper('body-style')
# Out:
# {'diesel': 0, 'gas': 1}
# {'turbo': 0, 'std': 1}
# {'convertible': 0, 'wagon': 1, 'hatchback': 2, 'hardtop': 3, 'sedan': 4}
# ({'convertible', 'hardtop', 'hatchback', 'sedan', 'wagon'},
#  {'convertible': 0, 'wagon': 1, 'hatchback': 2, 'hardtop': 3, 'sedan': 4})

# %%
mapper('engine-location')
mapper('engine-type')
mapper('fuel-system')
# Out:
# {'rear': 0, 'front': 1}
# {'dohc': 0, 'rotor': 1, 'ohcf': 2, 'ohcv': 3, 'l': 4, 'ohc': 5, 'dohcv': 6}
# {'spdi': 0, '2bbl': 1, 'spfi': 2, 'mpfi': 3, '1bbl': 4, 'mfi': 5, '4bbl': 6, 'idi': 7}
# ({'1bbl', '2bbl', '4bbl', 'idi', 'mfi', 'mpfi', 'spdi', 'spfi'},
#  {'spdi': 0,
#   '2bbl': 1,
#   'spfi': 2,
#   'mpfi': 3,
#   '1bbl': 4,
#   'mfi': 5,
#   '4bbl': 6,
#   'idi': 7})

# %%
mapper('drive-wheels')
# Out:
# {'rwd': 0, 'fwd': 1, '4wd': 2}
# ({'4wd', 'fwd', 'rwd'}, {'rwd': 0, 'fwd': 1, '4wd': 2})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    int32
#  2   make               205 non-null    int64
#  3   fuel-type          205 non-null    int64
#  4   aspiration         205 non-null    int64
#  5   num-of-doors       205 non-null    int64
#  6   body-style         205 non-null    int64
#  7   drive-wheels       205 non-null    int64
#  8   engine-location    205 non-null    int64
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    int64
#  15  num-of-cylinders   205 non-null    int64
#  16  engine-size        205 non-null    int64
#  17  fuel-system        205 non-null    int64
#  18  bore               205 non-null    float64
#  19  stroke             205 non-null    float64
#  20  compression-ratio  205 non-null    float64
#  21  horsepower         205 non-null    int32
#  22  peak-rpm           205 non-null    int32
#  23  city-mpg           205 non-null    int64
#  24  highway-mpg        205 non-null    int64
#  25  price              205 non-null    int32
# dtypes: float64(7), int32(4), int64(15)
# memory usage: 38.6 KB

# %%
Y = data.pop('price')

# %%
import sklearn
from sklearn.preprocessing import StandardScaler
StdSc = StandardScaler()
X = StdSc.fit_transform(data)
Y = Y / 1000

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,Y, random_state=42, test_size = 0.33)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
y_pred = y_predict.flatten()

print('r2:', r2_score(y_test,y_predict)) # Accuracy
print('MAE:', mean_absolute_error(y_test,y_predict))
print('RMSE:', (mean_squared_error(y_test,y_predict)**0.5))

plt.scatter(y_test, y_pred)
plt.plot(np.arange(0,50), np.arange(0, 50), color = 'green')
plt.grid(True)
# Out:
# Accuracy:  0.7994804192847697
# r2: 0.7994804192847697
# MAE: 2.6537625598466255
# RMSE: 3.605795621216656

# %% [markdown]
# ## Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
y_pred = y_predict.flatten()

print('r2:', r2_score(y_test,y_predict)) # Accuracy
print('MAE:', mean_absolute_error(y_test,y_predict))
print('RMSE:', (mean_squared_error(y_test,y_predict)**0.5))

plt.scatter(y_test, y_pred)
plt.plot(np.arange(0,50), np.arange(0, 50), color = 'green')
plt.grid(True)
# Out:
# Accuracy:  88.29146944573579
# r2: 0.8829146944573578
# MAE: 1.8396911764705886
# RMSE: 2.7553318338642776

# %% [markdown]
# ## Support Vector Regression

# %%
from sklearn.svm import SVR
model = SVR()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
y_pred = y_predict.flatten()

print('r2:', r2_score(y_test,y_predict)) # Accuracy
print('MAE:', mean_absolute_error(y_test,y_predict))
print('RMSE:', (mean_squared_error(y_test,y_predict)**0.5))

plt.scatter(y_test, y_pred)
plt.plot(np.arange(0,50), np.arange(0, 50), color = 'green')
plt.grid(True)
# Out:
# Accuracy:  46.260150788347076
# r2: 0.46260150788347076
# MAE: 3.1935175613373468
# RMSE: 5.9029748765133006
