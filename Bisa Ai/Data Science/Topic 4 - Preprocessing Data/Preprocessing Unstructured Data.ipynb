# %% [markdown]
# # Data Gambar

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
pth = 'python-logo.png'

# %% [markdown]
# Membaca dan menampilkan gambar

# %%
img = cv2.imread(pth)
plt.imshow(img)

# %% [markdown]
# Menampilkan ukuran panjang dan lebar gambar
# format : (panjang, lebar, jumlah channel)

# %%
print(img.shape)
# Out:
# (717, 860, 3)

# %% [markdown]
# Konversi channel pada gambar
# BGR -> RGB

# %%
imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
print(imgRGB.shape)
plt.imshow(imgRGB)
# Out:
# (717, 860, 3)

# %% [markdown]
# Konversi channel pada gambar
# BGR -> grayscale

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(gray.shape)
plt.imshow(gray, cmap='gray')
# Out:
# (717, 860)

# %% [markdown]
# Memotong (crop) gambar

# %%
crop = imgRGB[:,290:570]
plt.imshow(crop)

# %% [markdown]
# Mengubah ukuran (resizing) gambar dengan ukuran tetap

# %%
imgrsz = cv2.resize(imgRGB, (1000,1000))
print(imgrsz.shape)
plt.imshow(imgrsz)
# Out:
# (1000, 1000, 3)

# %% [markdown]
# Mengubah ukuran (resizing) gambar dengan ukuran skala

# %%
imgrsz = cv2.resize(imgRGB, (0,0), fx=2.5, fy= 2.5)
print(imgrsz.shape)
plt.imshow(imgrsz)
# Out:
# (1792, 2150, 3)

# %% [markdown]
# Geometrical Image Transformation - Rotation

# %%
imgrt= cv2.rotate(imgRGB, cv2.cv2.ROTATE_90_CLOCKWISE)
print(imgrt.shape)
plt.imshow(imgrt)
# Out:
# (860, 717, 3)

# %% [markdown]
# Binary thresholding

# %%
ret,thresh1 = cv2.threshold(gray,127,255,cv2.THRESH_BINARY)
ret,thresh2 = cv2.threshold(gray,127,255,cv2.THRESH_BINARY_INV)
print(thresh1.shape,thresh2.shape)
plt.subplot(121);plt.imshow(thresh1, cmap='gray')
plt.subplot(122);plt.imshow(thresh2, cmap='gray')
# Out:
# (717, 860) (717, 860)

# %% [markdown]
# Morphological Image Transformation - Erotion

# %%
imger = cv2.erode(thresh2, kernel = np.ones([5,5],np.uint8), iterations=5)
plt.subplot(121);plt.imshow(thresh2, cmap='gray')
plt.subplot(122);plt.imshow(imger, cmap='gray')

# %% [markdown]
# # Data Teks

# %%
#!pip install Sastrawi
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# Tokenisasi

# %%
kalimat = "berikut ini contoh tokenisasi data teks"
token = kalimat.split()
print(token)
# Out:
# ['berikut', 'ini', 'contoh', 'tokenisasi', 'data', 'teks']

# %%
tweet = 'Yg paLING gw SUka dr Python adalah gAMpang dipahami utk pemula.....'

# %% [markdown]
# Case folding

# %%
lowercase = tweet.lower()
print(lowercase)
# Out:
# yg paling gw suka dr python adalah gampang dipahami utk pemula.....

# %% [markdown]
# Menghapus karakter/simbol

# %%
tweet_alpha = lowercase.strip('.')
print(tweet_alpha)
# Out:
# yg paling gw suka dr python adalah gampang dipahami utk pemula

# %% [markdown]
# Slangword Handling

# %%
formal = {'gw':'saya','yg':'yang','dr':'dari','gampang':'mudah','utk':'untuk'}
slang = tweet_alpha.split()
slang = [formal[x] if x in formal.keys() else x for x in slang]
tweet_slang = ''.join(' '.join(x for x in slang))
print(tweet_slang)
# Out:
# yang paling saya suka dari python adalah mudah dipahami untuk pemula

# %% [markdown]
# Stemming

# %%
stemmer = StemmerFactory().create_stemmer()

tweet_stem = stemmer.stem(tweet_slang)
print(tweet_stem)
# Out:
# yang paling saya suka dari python adalah mudah paham untuk mula

# %% [markdown]
# Stopword Removal

# %%
stopword = StopWordRemoverFactory().create_stop_word_remover()

stopword.remove(tweet_stem)
# Out:
# 'paling suka python mudah paham mula'

# %% [markdown]
# Feature Extraction

# %%
corpus = [
  'This is the first document.',
  'This document is the second document.',
  'And this is the third one.',
  'Is this the first document?'
  ]
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(corpus)

# %%
vectorizer.get_feature_names()
# Out:
# ['and', 'document', 'first', 'is', 'one', 'second', 'the', 'third', 'this']

# %%
print(X.shape)
X
# Out:
# (4, 9)
# <4x9 sparse matrix of type '<class 'numpy.float64'>'
# 	with 21 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # Data Audio

# %%
import librosa
import librosa.display

# %% [markdown]
# Membaca data audio

# %%
# 1. Get the file path to an included audio example
# filename = librosa.example('nutcracker')
filename = 'Kevin_MacLeod_-_P_I_Tchaikovsky_Dance_of_the_Sugar_Plum_Fairy.ogg'


# 2. Load the audio as a waveform `y`
#    Store the sampling rate as `sr`
y, sr = librosa.load(filename)

# 3. Run the default beat tracker
tempo, beat_frames = librosa.beat.beat_track(y=y, sr=sr)

print('Estimated tempo: {:.2f} beats per minute'.format(tempo))
# Out:
# Estimated tempo: 107.67 beats per minute

# %% [markdown]
# Ekstraksi Fitur - Spectogram

# %%
librosa.feature.melspectrogram(y=y, sr=sr)
# Out:
# array([[1.1624643e-11, 2.9800769e-12, 2.6930164e-18, ..., 9.7236735e-16,
#         3.6693381e-13, 2.9155418e-11],
#        [1.2108101e-11, 3.1038470e-12, 2.1557146e-18, ..., 1.7243779e-15,
#         3.6618950e-13, 3.0045619e-11],
#        [1.2271250e-11, 3.1408821e-12, 2.5836358e-18, ..., 1.8678588e-15,
#         3.8181955e-13, 3.0519805e-11],
#        ...,
#        [1.0417331e-10, 4.3931893e-11, 2.7009572e-10, ..., 2.3992099e-08,
#         3.4866925e-08, 2.3285606e-08],
#        [5.7005347e-09, 8.7515080e-09, 1.3874865e-08, ..., 3.1039569e-08,
#         2.1043927e-08, 1.6056815e-08],
#        [1.9813518e-08, 3.9629807e-08, 3.9309448e-08, ..., 2.9675672e-08,
#         2.0104693e-08, 1.2806278e-08]], dtype=float32)

# %%
S = librosa.feature.melspectrogram(y=y, sr=sr)
fig, ax = plt.subplots()
S_dB = librosa.power_to_db(S, ref=np.max)
img = librosa.display.specshow(S_dB, x_axis='time',
                         y_axis='mel', sr=sr,
                         fmax=8000, ax=ax)
fig.colorbar(img, ax=ax, format='%+2.0f dB')
ax.set(title='Mel-frequency spectrogram')
# Out:
# [Text(0.5, 1.0, 'Mel-frequency spectrogram')]
