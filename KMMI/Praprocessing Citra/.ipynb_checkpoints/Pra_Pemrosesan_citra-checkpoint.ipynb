# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

import matplotlib.pyplot as plt

# %%
img = cv2.imread('eximage.jpg')
print(img.shape)
# cv2_imshow(img)
# Out:
# (225, 300, 3)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# plt.imshow(img)

# %%
h,w = img.shape[:2]
print(f'resolusi citra {w}x{h}')
# Out:
# resolusi citra 300x225

# %%
new_img = np.zeros([h,w,3], dtype='uint8')

for y in range(h):
  for x in range(w):
    new_img[y,x] = [0,48,128]

cv2_imshow(new_img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x225 at 0x7F377BA83FD0>

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
print(gray_img.shape)
cv2_imshow(gray_img)
# Out:
# (225, 300)
# <PIL.Image.Image image mode=L size=300x225 at 0x7F3776D8EC90>

# %%
negative_img = np.zeros([h,w], dtype='uint8')

for y in range(h):
  for x in range(w):
    pix = gray_img[y,x]
    negative_img[y,x] = 256 - 1 - pix

cv2_imshow(negative_img)
# Out:
# <PIL.Image.Image image mode=L size=300x225 at 0x7F3776A688D0>

# %%
trans_log_img = np.zeros([h,w], dtype='uint8')

for y in range(h):
  for x in range(w):
    pix = gray_img[y,x]
    val = 20 * np.log(1 + pix)
    if val > 255:
      val = 255
    if val < 0:
      val = 0
    trans_log_img[y,x] = val

cv2_imshow(trans_log_img)
# Out:
# <PIL.Image.Image image mode=L size=300x225 at 0x7F3776A08590>

# %%
powlaw_log_img = np.zeros([h,w], dtype='uint8')

for y in range(h):
  for x in range(w):
    pix = gray_img[y,x]
    val = 10 * np.power(pix, 0.67)
    if val > 255:
      val = 255
    if val < 0:
      val = 0
    powlaw_log_img[y,x] = val

cv2_imshow(powlaw_log_img)
# Out:
# <PIL.Image.Image image mode=L size=300x225 at 0x7F37764F0310>

# %%
hist = np.zeros([256], dtype='uint8')

for y in range(h):
  for x in range(w):
    pix = powlaw_log_img[y,x]
    hist[pix] += 1

plt.plot(hist)

# %%
hist_eq_img = cv2.equalizeHist(powlaw_log_img)
cv2_imshow(hist_eq_img)
# Out:
# <PIL.Image.Image image mode=L size=300x225 at 0x7F37764D4DD0>

# %%
(thresh, thresh_img) = cv2.threshold(gray_img, 127, 255, cv2.THRESH_BINARY)
cv2_imshow(thresh_img)
# Out:
# <PIL.Image.Image image mode=L size=300x225 at 0x7F37764C1390>

# %%
kernel = np.ones((5, 5), np.uint8)
erode_img = cv2.erode(thresh_img, kernel)
cv2_imshow(erode_img)
# Out:
# <PIL.Image.Image image mode=L size=300x225 at 0x7F3776498BD0>

# %%
kernel = np.ones((5, 5), np.uint8)
dilate_img = cv2.dilate(thresh_img, kernel)
cv2_imshow(dilate_img)
# Out:
# <PIL.Image.Image image mode=L size=300x225 at 0x7F37764F6290>
